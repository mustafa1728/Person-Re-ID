# %%
# %cd /content
# !gdown https://drive.google.com/uc?id=1E5oxyY1l868tFORB65gl01LHvgikoL5k
# !unzip -q AlignedReID.zip

# %%
# !pip install torch==0.4.1.post2 torchvision==0.2.1
# !pip install  numpy==1.15.0
# !pip install scipy==1.2.0
# Out:
# ...
#      |████████████████████████████████| 519.5 MB 23 kB/s
# ...
#      |████████████████████████████████| 54 kB 2.8 MB/s
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 1.10.0+cu111
#     Uninstalling torch-1.10.0+cu111:
#       Successfully uninstalled torch-1.10.0+cu111
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.11.1+cu111
#     Uninstalling torchvision-0.11.1+cu111:
#       Successfully uninstalled torchvision-0.11.1+cu111
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.11.0 requires torch==1.10.0, but you have torch 0.4.1.post2 which is incompatible.
# fastai 1.0.61 requires torch>=1.0.0, but you have torch 0.4.1.post2 which is incompatible.
# ...
#      |████████████████████████████████| 26.6 MB 76 kB/s
# ...
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.4.1
# ...

# %%
# %cd /content/AlignedReID
# !python3 train_alignedreid.py  -d reid780 -a resnet50 --test_distance global_local --reranking --labelsmooth --print-freq 7 --eval-step 20
# Out:
# /content/AlignedReID
# ...
# Args:Namespace(arch='resnet50', cuhk03_classic_split=False, cuhk03_labeled=False, dataset='reid780', eval_step=20, evaluate=False, gamma=0.1, gpu_devices='0', height=256, htri_only=False, labelsmooth=True, lr=0.0002, margin=0.3, max_epoch=300, num_instances=4, optim='adam', print_freq=7, reranking=True, resume='', root='data', save_dir='log', seed=1, split_id=0, start_epoch=0, start_eval=0, stepsize=150, test_batch=32, test_distance='global_local', train_batch=32, unaligned=False, use_cpu=False, use_metric_cuhk03=False, weight_decay=0.0005, width=128, workers=4)
# ...
# Currently using GPU 0
# Initializing dataset reid780
# => ReID780 loaded
# Dataset statistics:
#   ------------------------------
#   subset   | # ids | # images
#   ------------------------------
#   train    |    62 |      992
#   query    |    12 |       28
#   gallery  |    12 |      181
#   ------------------------------
#   total    |    74 |     1201
#   ------------------------------
# ...

# %%
# %cd /content/AlignedReID
# !python3 train_alignedreid.py  -d reid780 -a resnet101 --test_distance global_local --reranking --labelsmooth --print-freq 7 --eval-step 20 --max-epoch 100
# Out:
# /content/AlignedReID
# ...
# Args:Namespace(arch='resnet101', cuhk03_classic_split=False, cuhk03_labeled=False, dataset='reid780', eval_step=20, evaluate=False, gamma=0.1, gpu_devices='0', height=256, htri_only=False, labelsmooth=True, lr=0.0002, margin=0.3, max_epoch=100, num_instances=4, optim='adam', print_freq=7, reranking=True, resume='', root='data', save_dir='log', seed=1, split_id=0, start_epoch=0, start_eval=0, stepsize=150, test_batch=32, test_distance='global_local', train_batch=32, unaligned=False, use_cpu=False, use_metric_cuhk03=False, weight_decay=0.0005, width=128, workers=4)
# ...
# Currently using GPU 0
# Initializing dataset reid780
# => ReID780 loaded
# Dataset statistics:
#   ------------------------------
#   subset   | # ids | # images
#   ------------------------------
#   train    |    62 |      992
#   query    |    12 |       28
#   gallery  |    12 |      181
#   ------------------------------
#   total    |    74 |     1201
#   ------------------------------
# ...

# %%
# %cd /content/AlignedReID
# !python3 train_alignedreid.py  -d reid780 -a densenet121 --test_distance global_local --reranking --labelsmooth --print-freq 7 --eval-step 20 --max-epoch 100
# Out:
# /content/AlignedReID
# ...
# Args:Namespace(arch='densenet121', cuhk03_classic_split=False, cuhk03_labeled=False, dataset='reid780', eval_step=20, evaluate=False, gamma=0.1, gpu_devices='0', height=256, htri_only=False, labelsmooth=True, lr=0.0002, margin=0.3, max_epoch=100, num_instances=4, optim='adam', print_freq=7, reranking=True, resume='', root='data', save_dir='log', seed=1, split_id=0, start_epoch=0, start_eval=0, stepsize=150, test_batch=32, test_distance='global_local', train_batch=32, unaligned=False, use_cpu=False, use_metric_cuhk03=False, weight_decay=0.0005, width=128, workers=4)
# ...
# Currently using GPU 0
# Initializing dataset reid780
# => ReID780 loaded
# Dataset statistics:
#   ------------------------------
#   subset   | # ids | # images
#   ------------------------------
#   train    |    62 |      992
#   query    |    12 |       28
#   gallery  |    12 |      181
#   ------------------------------
#   total    |    74 |     1201
#   ------------------------------
# ...

# %%
# %cd /content/AlignedReID
# !python3 train_alignedreid.py  -d reid780 -a shufflenet --test_distance global_local --reranking --labelsmooth --print-freq 7 --eval-step 20 --max-epoch 100
# Out:
# /content/AlignedReID
# ...
# Args:Namespace(arch='shufflenet', cuhk03_classic_split=False, cuhk03_labeled=False, dataset='reid780', eval_step=20, evaluate=False, gamma=0.1, gpu_devices='0', height=256, htri_only=False, labelsmooth=True, lr=0.0002, margin=0.3, max_epoch=100, num_instances=4, optim='adam', print_freq=7, reranking=True, resume='', root='data', save_dir='log', seed=1, split_id=0, start_epoch=0, start_eval=0, stepsize=150, test_batch=32, test_distance='global_local', train_batch=32, unaligned=False, use_cpu=False, use_metric_cuhk03=False, weight_decay=0.0005, width=128, workers=4)
# ...
# Currently using GPU 0
# Initializing dataset reid780
# => ReID780 loaded
# Dataset statistics:
#   ------------------------------
#   subset   | # ids | # images
#   ------------------------------
#   train    |    62 |      992
#   query    |    12 |       28
#   gallery  |    12 |      181
#   ------------------------------
#   total    |    74 |     1201
#   ------------------------------
# ...

# %%
# %cd /content/AlignedReID
# !python3 train_alignedreid.py  -d reid780 -a inceptionv4 --test_distance global_local --reranking --labelsmooth --print-freq 7 --eval-step 20 --max-epoch 300
# Out:
# /content/AlignedReID
# ...
# Args:Namespace(arch='inceptionv4', cuhk03_classic_split=False, cuhk03_labeled=False, dataset='reid780', eval_step=20, evaluate=False, gamma=0.1, gpu_devices='0', height=256, htri_only=False, labelsmooth=True, lr=0.0002, margin=0.3, max_epoch=300, num_instances=4, optim='adam', print_freq=7, reranking=True, resume='', root='data', save_dir='log', seed=1, split_id=0, start_epoch=0, start_eval=0, stepsize=150, test_batch=32, test_distance='global_local', train_batch=32, unaligned=False, use_cpu=False, use_metric_cuhk03=False, weight_decay=0.0005, width=128, workers=4)
# ...
# Currently using GPU 0
# Initializing dataset reid780
# => ReID780 loaded
# Dataset statistics:
#   ------------------------------
#   subset   | # ids | # images
#   ------------------------------
#   train    |    62 |      992
#   query    |    12 |       28
#   gallery  |    12 |      181
#   ------------------------------
#   total    |    74 |     1201
#   ------------------------------
# ...
