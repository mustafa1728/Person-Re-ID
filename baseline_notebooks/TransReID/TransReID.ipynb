# %%
# %cd /content
# !gdown https://drive.google.com/uc?id=1HWQWPqh3o7wRcSrfn8vUhFJueE8lxlKA
# !unzip -q TransReID.zip

# !gdown https://drive.google.com/uc?id=1tewwif1w5YKrkVFkXIHOJKKjQqmPBHz2
# Out:
# /content
# Downloading...
# From: https://drive.google.com/uc?id=1tewwif1w5YKrkVFkXIHOJKKjQqmPBHz2
# To: /content/transformer_120.pth
# 100% 404M/404M [00:04<00:00, 83.6MB/s]

# %%
# %cd /content/TransReID
# !pip install -r requirements.txt

# !pip install torch==1.8.1+cu111 torchvision==0.9.1+cu111 torchaudio==0.8.1 -f https://download.pytorch.org/whl/lts/1.8/torch_lts.html
# !pip install torchtext==0.9.1
# Out:
# /content/TransReID
# ...
#      |████████████████████████████████| 376 kB 5.3 MB/s
# ...
# Looking in links: https://download.pytorch.org/whl/lts/1.8/torch_lts.html
# ...
#      |█████████████▌                  | 834.1 MB 1.9 MB/s eta 0:10:14tcmalloc: large alloc 1147494400 bytes == 0x556502ed0000 @  0x7f3823707615 0x5565002074cc 0x5565002e747a 0x55650020a2ed 0x5565002fbe1d 0x55650027de99 0x5565002789ee 0x55650020bbda 0x55650027dd00 0x5565002789ee 0x55650020bbda 0x55650027a737 0x5565002fcc66 0x556500279daf 0x5565002fcc66 0x556500279daf 0x5565002fcc66 0x556500279daf 0x55650020c039 0x55650024f409 0x55650020ac52 0x55650027dc25 0x5565002789ee 0x55650020bbda 0x55650027a737 0x5565002789ee 0x55650020bbda 0x556500279915 0x55650020bafa 0x556500279c0d 0x5565002789ee
# ...

# %%
 # %cd /content/TransReID
# !python train.py --config_file configs/ReID780/vit_transreid.yml
# Out:
# /content/TransReID
# 2021-11-19 13:49:05,166 transreid INFO: Saving model in the path :./logs/reid780
# 2021-11-19 13:49:05,167 transreid INFO: Namespace(config_file='configs/ReID780/vit_transreid.yml', local_rank=0, opts=[])
# 2021-11-19 13:49:05,167 transreid INFO: Loaded configuration file configs/ReID780/vit_transreid.yml
# 2021-11-19 13:49:05,167 transreid INFO:
# MODEL:
#   PRETRAIN_CHOICE: 'imagenet'
#   PRETRAIN_PATH: '/content/transformer_120.pth'
#   METRIC_LOSS_TYPE: 'triplet'
#   IF_LABELSMOOTH: 'off'
#   IF_WITH_CENTER: 'no'
#   NAME: 'transformer'
#   NO_MARGIN: True
#   DEVICE_ID: ('0')
#   TRANSFORMER_TYPE: 'vit_base_patch16_224_TransReID'
#   STRIDE_SIZE: [16, 16]
#   SIE_CAMERA: True
#   SIE_COE: 3.0
#   JPM: True
#   RE_ARRANGE: True
#
# INPUT:
#   SIZE_TRAIN: [256, 128]
#   SIZE_TEST: [256, 128]
#   PROB: 0.5 # random horizontal flip
#   RE_PROB: 0.5 # random erasing
#   PADDING: 10
#   PIXEL_MEAN: [0.5, 0.5, 0.5]
#   PIXEL_STD: [0.5, 0.5, 0.5]
#
# DATASETS:
# ...
